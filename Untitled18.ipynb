# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathri26062006/gayuu/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name,Age,Marks
Ramya,21,85
Shree,20,95
Rakshaya,18,80
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-42ed974961bc> in <cell line: 0>()
# ----> 1 Name,Age,Marks
#       2 Ramya,21,90
#       3 Shree,20,85
#       4 Rakshaya,18,80
#
# NameError: name 'Name' is not defined

# %%
import pandas as pd

# Read the csv file
data=pd.read_csv("/content/archive (1).zip")

# Show first 5 rows
print(data.head())

# Describe the dataset (summary stats)
print(data.describe())

# Create a new 'Marks' column as the average of all 3 scores
data["Marks"]=data[["math score","writing score","reading score"]].mean(axis=1)

# Access the new 'Marks' column
print("Marks column:")
print(data["Marks"])

# Filter data
print("Students with marks >90:")
print(data[data["Marks"]>90])
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1  female        group D            some high school  free/reduced
# 2    male        group E                some college  free/reduced
# 3    male        group B                 high school      standard
# 4    male        group E          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          67             67             63
# 1                    none          40             59             55
# 2                    none          59             60             50
# 3                    none          77             78             68
# 4               completed          78             73             68
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.396000      69.002000      67.738000
# ...
